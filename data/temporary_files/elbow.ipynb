# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("inertias.csv", sep=";",index_col=0)
df = df[:34]
df.tail()
# Out:
#            0
# 30  1.165879
# 31  0.795106
# 32  0.453089
# 33  0.325791
# 34  0.170255

# %%
ax = df.plot(loglog=True)
ax.set_xlabel("Number of clusters (log)")
ax.set_ylabel("Distortion (log)")
ax.set_title("Elbow method (log)")
# Out:
# Text(0.5, 1.0, 'Elbow method (log)')
